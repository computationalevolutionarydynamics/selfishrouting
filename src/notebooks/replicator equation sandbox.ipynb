# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %run ../python/network.py

# %%
G = create_braess_network()

# %%
nx.draw_networkx(G)

# %%
# %run ../python/replicator_equation.py

# %%
t_vector = np.linspace(0, 20, 1500)

# %%
pop = [0.1, 0.2, 0.2, 0.5]

# %%
t = ReplicatorDynamics(G, 5)

# %%
t.replicator_trajectory(t_vector, pop ,maximum_iterations= 95000)
# Out:
# 0.0836757367494
# 0.135428539944
# 0.645467183421
# 0.135428539885

# %%
t.replicator_mutator_trajectory(t_vector, pop ,u= 0.005, maximum_iterations= 95000)
# Out:
# 0.0791814575053
# 0.131376639772
# 0.658065262909
# 0.131376639814

# %%
# %run ../python/selfish_routing.py

# %%
test = MoranProcess(graph=G, number_of_players=5, w=10, mutation_probability=0.005, population_array=[10, 20, 20, 50], seed=123)

# %%
df = test.run_time_series(1000, 100)

# %%
df.plot()

# %%
df.mean()
# Out:
# SABT     9.000000
# SAT     13.909091
# SBAT    59.454545
# SBT     17.636364
# dtype: float64
